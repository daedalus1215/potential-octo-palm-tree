# %%
import json
from binance import Client
import pandas as pd

# %%
def get_api_essentals(data):
    return data['api_key'], data['api_secret']


with open('./settings.json', 'r') as file:
    data = json.load(file)

api_key, api_secret = get_api_essentals(data)

client = Client(api_key=api_key, api_secret=api_secret, tld="us")

# %%
timestamp = client._get_earliest_valid_timestamp(symbol = "BTCUSDT", interval = "1d")
timestamp
# Out:
# 1569196800000

# %%
pd.to_datetime(timestamp, unit = "ms")
# Out:
# Timestamp('2019-09-23 00:00:00')

# %%
bars = client.get_historical_klines(symbol = "BTCUSDT", 
                                    interval = "1d", 
                                    start_str = timestamp, 
                                    limit = 1000)
bars
# Out:
# [[1569196800000,
#   '9930.13000000',
#   '9930.13000000',
#   '9930.13000000',
#   '9930.13000000',
#   '0.00100000',
#   1569283199999,
#   '9.93013000',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569283200000,
#   '9637.93000000',
#   '9665.05000000',
#   '7996.45000000',
#   '8519.67000000',
#   '202.35079900',
#   1569369599999,
#   '1739432.08920509',
#   2345,
#   '125.93546400',
#   '1075623.60280331',
#   '0'],
#  [1569369600000,
#   '8528.12000000',
#   '8724.77000000',
#   '8247.78000000',
#   '8435.28000000',
#   '55.41797100',
#   1569455999999,
#   '469361.69055629',
#   763,
#   '29.05942700',
#   '246049.20514584',
#   '0'],
#  [1569456000000,
#   '8434.45000000',
#   '8453.20000000',
#   '7761.87000000',
#   '8064.41000000',
#   '41.88007900',
#   1569542399999,
#   '340923.66601370',
#   1023,
#   '19.80884900',
#   '161115.44149782',
#   '0'],
#  [1569542400000,
#   '8078.75000000',
#   '8259.96000000',
#   '7858.58000000',
#   '8178.73000000',
# ...

# %%
df = pd.DataFrame(bars)
df
# Out:
#                  0               1               2               3   \
# 0     1569196800000   9930.13000000   9930.13000000   9930.13000000
# 1     1569283200000   9637.93000000   9665.05000000   7996.45000000
# 2     1569369600000   8528.12000000   8724.77000000   8247.78000000
# 3     1569456000000   8434.45000000   8453.20000000   7761.87000000
# 4     1569542400000   8078.75000000   8259.96000000   7858.58000000
# ...             ...             ...             ...             ...
# 1244  1676678400000  24570.72000000  24875.05000000  24436.84000000
# 1245  1676764800000  24630.43000000  25193.38000000  24202.59000000
# 1246  1676851200000  24266.76000000  25113.40000000  23844.34000000
# 1247  1676937600000  24835.34000000  25242.62000000  24145.47000000
# 1248  1677024000000  24448.90000000  24473.50000000  23583.63000000
#
#                   4              5              6                  7      8   \
# ...

# %% [markdown]
# ### Add a date column

# %%
df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")

# %%
df
# Out:
#                   0               1               2               3  \
# 0     1569196800000   9930.13000000   9930.13000000   9930.13000000
# 1     1569283200000   9637.93000000   9665.05000000   7996.45000000
# 2     1569369600000   8528.12000000   8724.77000000   8247.78000000
# 3     1569456000000   8434.45000000   8453.20000000   7761.87000000
# 4     1569542400000   8078.75000000   8259.96000000   7858.58000000
# ...             ...             ...             ...             ...
# 1244  1676678400000  24570.72000000  24875.05000000  24436.84000000
# 1245  1676764800000  24630.43000000  25193.38000000  24202.59000000
# 1246  1676851200000  24266.76000000  25113.40000000  23844.34000000
# 1247  1676937600000  24835.34000000  25242.62000000  24145.47000000
# 1248  1677024000000  24448.90000000  24473.50000000  23583.63000000
#
#                    4              5              6                  7      8  \
# ...

# %% [markdown]
# ### Slap headers onto the columns

# %%
df.columns = [
    "Open Time",
    "Open",
    "High",
    "Low",
    "Close",
    "Volume",
    "Close Time",
    "Quote Asset Volume",
    "Number of Trades",
    "Taker Buy Base Asset Volume",
    "Taker Buy Quote Asset Volume",
    "Ignore",
    "Date"
]
df
# Out:
#           Open Time            Open            High             Low  \
# 0     1569196800000   9930.13000000   9930.13000000   9930.13000000
# 1     1569283200000   9637.93000000   9665.05000000   7996.45000000
# 2     1569369600000   8528.12000000   8724.77000000   8247.78000000
# 3     1569456000000   8434.45000000   8453.20000000   7761.87000000
# 4     1569542400000   8078.75000000   8259.96000000   7858.58000000
# ...             ...             ...             ...             ...
# 1244  1676678400000  24570.72000000  24875.05000000  24436.84000000
# 1245  1676764800000  24630.43000000  25193.38000000  24202.59000000
# 1246  1676851200000  24266.76000000  25113.40000000  23844.34000000
# 1247  1676937600000  24835.34000000  25242.62000000  24145.47000000
# 1248  1677024000000  24448.90000000  24473.50000000  23583.63000000
#
#                Close         Volume     Close Time Quote Asset Volume  \
# 0      9930.13000000     0.00100000  1569283199999         9.93013000
# ...

# %% [markdown]
# ### Override df with the most important data

# %%
df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()

# %%
df
# Out:
#            Date            Open            High             Low  \
# 0    2019-09-23   9930.13000000   9930.13000000   9930.13000000
# 1    2019-09-24   9637.93000000   9665.05000000   7996.45000000
# 2    2019-09-25   8528.12000000   8724.77000000   8247.78000000
# 3    2019-09-26   8434.45000000   8453.20000000   7761.87000000
# 4    2019-09-27   8078.75000000   8259.96000000   7858.58000000
# ...         ...             ...             ...             ...
# 1244 2023-02-18  24570.72000000  24875.05000000  24436.84000000
# 1245 2023-02-19  24630.43000000  25193.38000000  24202.59000000
# 1246 2023-02-20  24266.76000000  25113.40000000  23844.34000000
# 1247 2023-02-21  24835.34000000  25242.62000000  24145.47000000
# 1248 2023-02-22  24448.90000000  24473.50000000  23583.63000000
#
#                Close         Volume
# 0      9930.13000000     0.00100000
# 1      8519.67000000   202.35079900
# 2      8435.28000000    55.41797100
# 3      8064.41000000    41.88007900
# ...

# %%
### Set the Date column as the index, then set it in place to actually save the changes in place.

# %%
df.set_index("Date", inplace = True)

# %%
df
# Out:
#                       Open            High             Low           Close  \
# Date
# 2019-09-23   9930.13000000   9930.13000000   9930.13000000   9930.13000000
# 2019-09-24   9637.93000000   9665.05000000   7996.45000000   8519.67000000
# 2019-09-25   8528.12000000   8724.77000000   8247.78000000   8435.28000000
# 2019-09-26   8434.45000000   8453.20000000   7761.87000000   8064.41000000
# 2019-09-27   8078.75000000   8259.96000000   7858.58000000   8178.73000000
# ...                    ...             ...             ...             ...
# 2023-02-18  24570.72000000  24875.05000000  24436.84000000  24628.46000000
# 2023-02-19  24630.43000000  25193.38000000  24202.59000000  24263.00000000
# 2023-02-20  24266.76000000  25113.40000000  23844.34000000  24838.09000000
# 2023-02-21  24835.34000000  25242.62000000  24145.47000000  24453.24000000
# 2023-02-22  24448.90000000  24473.50000000  23583.63000000  23837.67000000
#
#                    Volume
# Date
# 2019-09-23     0.00100000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1249 entries, 2019-09-23 to 2023-02-22
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1249 non-null   object
#  1   High    1249 non-null   object
#  2   Low     1249 non-null   object
#  3   Close   1249 non-null   object
#  4   Volume  1249 non-null   object
# dtypes: object(5)
# memory usage: 58.5+ KB

# %%
### iterate over the columns and convert them into numeric

# %%
for column in df.columns:
    df[column] = pd.to_numeric(df[column], errors = "coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1249 entries, 2019-09-23 to 2023-02-22
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1249 non-null   float64
#  1   High    1249 non-null   float64
#  2   Low     1249 non-null   float64
#  3   Close   1249 non-null   float64
#  4   Volume  1249 non-null   float64
# dtypes: float64(5)
# memory usage: 58.5 KB

# %%
def get_history(symbol, interval, start, end = None):
    bars = client.get_historical_klines(symbol=symbol, interval = interval, start_str=start, end_str = end, limit=1000)
    
    df = pd.DataFrame(bars)
    df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")
    df.columns = [
    "Open Time",
    "Open",
    "High",
    "Low",
    "Close",
    "Volume",
    "Close Time",
    "Quote Asset Volume",
    "Number of Trades",
    "Taker Buy Base Asset Volume",
    "Taker Buy Quote Asset Volume",
    "Ignore",
    "Date"]
    
    df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()
    df.set_index("Date", inplace=True)
    for column in df.columns:
        df[column] = pd.to_numeric(df[column], errors = "coersce")

    return df

# %%
timestamp
# Out:
# 1569196800000

# %%
df = get_history(symbol="BTCUSDT", interval = "1d", start=timestamp)
df
# Out:
#                 Open      High       Low     Close       Volume
# Date
# 2019-09-23   9930.13   9930.13   9930.13   9930.13     0.001000
# 2019-09-24   9637.93   9665.05   7996.45   8519.67   202.350799
# 2019-09-25   8528.12   8724.77   8247.78   8435.28    55.417971
# 2019-09-26   8434.45   8453.20   7761.87   8064.41    41.880079
# 2019-09-27   8078.75   8259.96   7858.58   8178.73    47.142904
# ...              ...       ...       ...       ...          ...
# 2023-02-18  24570.72  24875.05  24436.84  24628.46  1141.060212
# 2023-02-19  24630.43  25193.38  24202.59  24263.00  1744.260125
# 2023-02-20  24266.76  25113.40  23844.34  24838.09  1988.734029
# 2023-02-21  24835.34  25242.62  24145.47  24453.24  2484.635281
# 2023-02-22  24448.90  24473.50  23583.63  23847.63  1929.011035
#
# [1249 rows x 5 columns]

# %%
df.info()

# %%
df = get_history(symbol="BTCUSDT", interval = "1d", start="2021-01-01", end="2021-06-30")
df
# Out:
#                 Open      High       Low     Close       Volume
# Date
# 2021-01-01  28933.86  29611.51  28649.46  29305.29   298.357085
# 2021-01-02  29321.41  33271.38  28955.02  32162.01   667.482338
# 2021-01-03  32174.75  34776.59  31942.96  33031.74   701.951087
# 2021-01-04  33034.55  33593.47  27500.00  32005.27   987.279894
# 2021-01-05  31996.54  34392.59  29937.69  33946.09   765.314265
# ...              ...       ...       ...       ...          ...
# 2021-06-26  31578.88  32711.25  30161.20  32271.79  1662.163429
# 2021-06-27  32294.65  34748.64  32000.19  34692.49  1102.643534
# 2021-06-28  34709.02  35285.42  33884.84  34487.91   731.538894
# 2021-06-29  34487.57  36605.26  34235.93  35922.17   656.549450
# 2021-06-30  35894.90  36088.87  34013.34  35036.58   558.669277
#
# [181 rows x 5 columns]

# %%
df = get_history(symbol="BTCUSDT", interval = "1M", start="2021-01-01", end="2021-06-15")
df
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2021-01-01  28933.86  41958.85  27500.00  33071.34  18490.374109
# 2021-02-01  33097.72  58361.09  32287.34  45161.60  11276.334712
# 2021-03-01  45161.20  61822.09  44950.13  58773.06   8625.403890
# 2021-04-01  58747.08  64853.59  46957.72  57707.15  17029.513648
# 2021-05-01  57698.27  59615.90  30116.81  37278.91  37741.439743
# 2021-06-01  37260.86  41356.90  28812.78  35036.58  30533.228528

# %%
#### Intraday Data (1H) for specified Time Period

# %%
df = get_history(symbol="BTCUSDT", interval="1h", start="2021-10-01", end="2021-10-05")
df
# Out:
#                          Open      High       Low     Close     Volume
# Date
# 2021-10-01 00:00:00  43825.91  44050.14  43688.96  43764.57  12.248661
# 2021-10-01 01:00:00  43710.62  43799.97  43430.29  43737.62   5.677891
# 2021-10-01 02:00:00  43736.48  43786.53  43296.61  43379.08   5.356909
# 2021-10-01 03:00:00  43395.72  43672.08  43347.50  43637.13   4.532391
# 2021-10-01 04:00:00  43660.39  43694.90  43474.14  43606.99   3.331595
# ...                       ...       ...       ...       ...        ...
# 2021-10-04 20:00:00  49394.69  49472.19  48963.31  48987.76   8.260270
# 2021-10-04 21:00:00  48979.56  49149.38  48555.97  48888.98   7.042640
# 2021-10-04 22:00:00  48918.53  49058.19  48693.89  48912.26   6.199231
# 2021-10-04 23:00:00  48925.42  49439.59  48912.26  49209.86   9.156379
# 2021-10-05 00:00:00  49209.98  49786.52  49048.35  49523.86  13.106619
#
# [97 rows x 5 columns]

# %%
### Most recent (last 2 hours) Intraday Data (1m)

# %%
from datetime import datetime, timedelta

# %%
now = datetime.utcnow()
now
# Out:
# datetime.datetime(2023, 2, 23, 1, 40, 35, 265262)

# %%
two_hours_before = now - timedelta(hours = 2)

# %%
two_hours_before
# Out:
# datetime.datetime(2023, 2, 22, 23, 40, 35, 265262)

# %%
str(two_hours_before)
# Out:
# '2023-02-22 23:40:35.265262'

# %%
df = get_history(symbol="BTCUSDT", interval="1m", start=str(two_hours_before))
df
# Out:
#                          Open      High       Low     Close    Volume
# Date
# 2023-02-22 23:41:00  24116.98  24123.96  24116.98  24123.96  0.130094
# 2023-02-22 23:42:00  24124.32  24129.39  24118.20  24123.91  1.486323
# 2023-02-22 23:43:00  24126.25  24133.32  24126.25  24133.32  0.106360
# 2023-02-22 23:44:00  24134.14  24135.22  24124.62  24126.54  0.536494
# 2023-02-22 23:45:00  24130.02  24133.53  24119.02  24126.34  1.392793
# ...                       ...       ...       ...       ...       ...
# 2023-02-23 01:39:00  24167.83  24170.44  24155.46  24156.92  0.637138
# 2023-02-23 01:40:00  24155.04  24162.06  24150.49  24152.42  0.901578
# 2023-02-23 01:41:00  24155.31  24155.31  24145.39  24145.65  0.445706
# 2023-02-23 01:42:00  24145.66  24153.64  24141.84  24145.46  1.729777
# 2023-02-23 01:43:00  24148.91  24151.18  24148.87  24151.18  0.097461
#
# [123 rows x 5 columns]

# %%
### Excursus: Loading Historical Data (csv) from website

# %%
url = r"~/Downloads/BTCUSDT-1h-2023-02-21.csv";
url
# Out:
# '~/Downloads/BTCUSDT-1h-2023-02-21.csv'

# %%
df = pd.read_csv(url, header = None)
df
# Out:
#                0         1         2         3         4            5   \
# 0   1676937600000  24843.89  24940.00  24781.50  24858.60   9572.17147
# 1   1676941200000  24858.60  24931.26  24802.34  24863.71   8886.39289
# 2   1676944800000  24862.93  25093.23  24856.04  24911.51  16178.83505
# 3   1676948400000  24910.32  25014.35  24847.00  24926.56  12852.50050
# 4   1676952000000  24926.56  24944.60  24854.18  24904.14   8327.66420
# 5   1676955600000  24904.98  24964.40  24870.27  24945.37   7866.30038
# 6   1676959200000  24946.44  25045.04  24923.34  25032.42  10204.55976
# 7   1676962800000  25033.02  25050.00  24936.99  24999.95  11468.50901
# 8   1676966400000  24999.77  25250.00  24627.44  24689.23  38341.94145
# 9   1676970000000  24689.66  24836.98  24555.55  24799.99  18067.19612
# 10  1676973600000  24799.99  24806.98  24675.39  24702.72  13804.76634
# 11  1676977200000  24703.20  24755.00  24561.58  24572.83  15964.92870
# ...

# %%
df['Date'] = pd.to_datetime(df.iloc[:, 0], unit = "ms")
df
# Out:
#                 0         1         2         3         4            5  \
# 0   1676937600000  24843.89  24940.00  24781.50  24858.60   9572.17147
# 1   1676941200000  24858.60  24931.26  24802.34  24863.71   8886.39289
# 2   1676944800000  24862.93  25093.23  24856.04  24911.51  16178.83505
# 3   1676948400000  24910.32  25014.35  24847.00  24926.56  12852.50050
# 4   1676952000000  24926.56  24944.60  24854.18  24904.14   8327.66420
# 5   1676955600000  24904.98  24964.40  24870.27  24945.37   7866.30038
# 6   1676959200000  24946.44  25045.04  24923.34  25032.42  10204.55976
# 7   1676962800000  25033.02  25050.00  24936.99  24999.95  11468.50901
# 8   1676966400000  24999.77  25250.00  24627.44  24689.23  38341.94145
# 9   1676970000000  24689.66  24836.98  24555.55  24799.99  18067.19612
# 10  1676973600000  24799.99  24806.98  24675.39  24702.72  13804.76634
# 11  1676977200000  24703.20  24755.00  24561.58  24572.83  15964.92870
# ...

# %%
df.columns = ["Open Time", "Open", "High", "Low", "Close", "Volume", "Close Time", "Quote Asset Volume", "Number of Trades", "Taker bu base asset volume", "Taker bu quoter asset volume", "ignore", "date"]
df
# Out:
#         Open Time      Open      High       Low     Close       Volume  \
# 0   1676937600000  24843.89  24940.00  24781.50  24858.60   9572.17147
# 1   1676941200000  24858.60  24931.26  24802.34  24863.71   8886.39289
# 2   1676944800000  24862.93  25093.23  24856.04  24911.51  16178.83505
# 3   1676948400000  24910.32  25014.35  24847.00  24926.56  12852.50050
# 4   1676952000000  24926.56  24944.60  24854.18  24904.14   8327.66420
# 5   1676955600000  24904.98  24964.40  24870.27  24945.37   7866.30038
# 6   1676959200000  24946.44  25045.04  24923.34  25032.42  10204.55976
# 7   1676962800000  25033.02  25050.00  24936.99  24999.95  11468.50901
# 8   1676966400000  24999.77  25250.00  24627.44  24689.23  38341.94145
# 9   1676970000000  24689.66  24836.98  24555.55  24799.99  18067.19612
# 10  1676973600000  24799.99  24806.98  24675.39  24702.72  13804.76634
# 11  1676977200000  24703.20  24755.00  24561.58  24572.83  15964.92870
# ...
